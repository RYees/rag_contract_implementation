# %%
import pandas as pd
import pprint
from datasets import Dataset, DatasetDict
from ragas.metrics import (
    answer_relevancy,
    faithfulness,
    context_precision,
    context_recall,
)
from ragas import evaluate

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-proj-Tzc9mrWyEFVxyDsq5HiWT3BlbkFJxp47toOztG4XRILBeRxr"

# %% [markdown]
# # Trying Ragas

# %%
drf = amnesty_qa["eval"].to_pandas()
pprint.pp(drf['contexts'][0])
type(drf['contexts'][0])
# Out:
# array(["- In 2022, the USA Supreme Court handed down a decision ruling that overturned 50 years of jurisprudence recognizing a constitutional right to abortion.\n- This decision has had a massive impact: one in three women and girls of reproductive age now live in states where abortion access is either totally or near-totally inaccessible.\n- The states with the most restrictive abortion laws have the weakest maternal health support, higher maternal death rates, and higher child poverty rates.\n- The USA Supreme Court ruling has also had impacts beyond national borders due to the geopolitical and cultural influence wielded by the USA globally and the aid it funds.\n- SRR organizations and activists across the world have expressed fear about the ruling laying the groundwork for anti-abortion legislative and policy attacks in other countries.\n- Advocates have also observed the ruling's impact on progressive law reform and the stalling of the adoption and enforcement of abortion guidelines in certain African countries.\n- The ruling has created a chilling effect in international policy spaces, emboldening anti-abortion state and non-state actors to undermine human rights protections.",
#        'The USA Supreme Court ruling on abortion has sparked intense debates and discussions not only within the country but also around the world. Many countries look to the United States as a leader in legal and social issues, so the decision could potentially influence the policies and attitudes towards abortion in other nations.',
#        "The ruling may also impact international organizations and non-governmental groups that work on reproductive rights and women's health issues. Depending on the outcome, there could be shifts in funding, advocacy efforts, and collaborations with American counterparts, leading to ripple effects in the global fight for reproductive justice."],
#       dtype=object)
# numpy.ndarray

# %%
from ragas.metrics import (
    answer_relevancy,
    faithfulness,
    context_recall,
    context_relevancy,
    context_precision,
)

from ragas import evaluate

result = evaluate(
    amnesty_qa["eval"],
    metrics=[
        context_precision,
        faithfulness,
        answer_relevancy,
        context_recall,
    ],
)

dff = result.to_pandas()
dff.head()
# Out:
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]
#                                             question  \
# 0  What are the global implications of the USA Su...
# 1  Which companies are the main contributors to G...
# 2  Which private companies in the Americas are th...
# 3  What action did Amnesty International urge its...
# 4  What are the recommendations made by Amnesty I...
#
#                                         ground_truth  \
# 0  The global implications of the USA Supreme Cou...
# 1  According to the Carbon Majors database, the m...
# 2  The largest private companies in the Americas ...
# 3  Amnesty International urged its supporters to ...
# 4  The recommendations made by Amnesty Internatio...
#
#                                               answer  \
# 0  The global implications of the USA Supreme Cou...
# 1  According to the Carbon Majors database, the m...
# 2  According to the Carbon Majors database, the l...
# 3  Amnesty International urged its supporters to ...
# 4  Amnesty International made several recommendat...
#
#                                             contexts  faithfulness  \
# 0  [- In 2022, the USA Supreme Court handed down ...      0.357143
# 1  [In recent years, there has been increasing pr...      0.080000
# 2  [The issue of greenhouse gas emissions has bec...      0.000000
# 3  [In the case of the Ogoni 9, Amnesty Internati...      0.400000
# 4  [In recent years, Amnesty International has fo...      0.047619
#
#    answer_relevancy  context_recall
# 0          0.987989             1.0
# 1          0.965289             1.0
# 2          0.991972             1.0
# 3          0.986490             1.0
# 4          0.989104             1.0

# %% [markdown]
# # Legal Contract Ragas Evaluation

# %%
evaluation_data = pd.read_csv('../data/updated_raptor_evaluation.csv')
eval = evaluation_data.drop('Unnamed: 0', axis=1)
eval.head()
dataset = Dataset.from_dict(eval)

# %%
eval["contexts"][4]
# Out:
# ["['the Escrow Agreement). \\nSection 2.08  Escrow.   \\n(a) At Closing, Buyer will deposit the Escrow Amount in escrow on behalf of the \\nSellers in accordance with the Escrow Agreement.  The Escrow Amount shall be held and, \\nsubject to Section 2.07, released to the Company Securityholders in accordance with the', 'the Escrow Agreement (and any remaining balance of the Escrow Amount not required to be \\npaid to the Buyer shall be released to Company Securityholders in accordance with the terms of \\nthe Escrow Agreement). \\nSection 2.08  Escrow.   \\n(a) At Closing, Buyer will deposit the Escrow Amount in escrow on behalf of the', 'by the terms of the Escrow Agreement.  All funds contained in the Escrow Account shall be held \\nin escrow and shall be available solely for the purpose of satisfying obligations of the Company \\nSecurityholders, if any, as provided in Section 2.07(f). \\nSection 2.05  Closing Deliveries. \\n(a) Buyer Closing Deliveries.  Upon the terms and subject to the conditions set forth', '(b) At the Closing, Buyer shall deposit the Escrow Amount with the Escrow Agent to \\nbe held in a separate account (the “Escrow Account ”).  The Escrow Account shall be governed \\nby the terms of the Escrow Agreement.  All funds contained in the Escrow Account shall be held \\nin escrow and shall be available solely for the purpose of satisfying obligations of the Company']"]

# %%
dataset
# Out:
# Dataset({
#     features: ['question', 'ground_truth', 'answer', 'contexts'],
#     num_rows: 14
# })

# %%
# Create a Dataset from the 'eval' DataFrame
# eval_dataset = Dataset.from_pandas(eval)

# # Rename the columns to match the expected format
# eval_dataset = eval_dataset.rename_columns({
#     'question': 'question',
#     'ground_truth': 'ground_truth',
#     'answer': 'answer',
#     'contexts': 'contexts'
# })

# %%
# eval_dataset = eval_dataset.map(lambda example: {"contexts": [context.replace("\n", " ") for context in example["contexts"]]})
# eval_dataset["contexts"][4]

# %%
try:
    result = evaluate(
        eval_dataset,
        metrics=[
            context_precision,
            faithfulness,
            answer_relevancy,
            context_recall,
        ],
        raise_exceptions=False,
    )
    pprint.pp(result)
    # dff = result.to_pandas()
    # dff.head()
except Exception as e:
    print(f"Error occurred during evaluation: {e}")
# Out:
# Error occurred during evaluation: Dataset feature "contexts" should be of type Sequence[string], got <class 'datasets.features.features.Value'>

# %%
# Assuming `eval_dataset` is the second dataset
# eval_dataset = eval_dataset.map(lambda example: {"contexts": list(example["contexts"])})
# dataset = Dataset.from_dict(eval_dataset)
try:
    result = evaluate(
        dataset=dataset,
        metrics=[
            context_precision,
            faithfulness,
            answer_relevancy,
            context_recall,
        ],
        raise_exceptions=True
    )
    dff = result.to_pandas()
    dff.head()
except Exception as e:
    print(f"Error occurred during evaluation: {e}")
    print(dataset.features)
# Out:
# Error occurred during evaluation: Dataset feature "contexts" should be of type Sequence[string], got <class 'datasets.features.features.Value'>
# {'question': Value(dtype='string', id=None), 'ground_truth': Value(dtype='string', id=None), 'answer': Value(dtype='string', id=None), 'contexts': Value(dtype='string', id=None)}

# %%
eval_dataset = eval_dataset.map(lambda example: {"contexts": list(example["contexts"])})
eval_dataset
# Out:
# Map:   0%|          | 0/14 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'ground_truth', 'answer', 'contexts'],
#     num_rows: 14
# })

# %% [markdown]
# parent doc approach ragas

# %%
import pandas as pd
from datasets import Dataset

evaluation_data = pd.read_csv('../data/updated_raptor_evaluation.csv')
eval = evaluation_data.drop('Unnamed: 0', axis=1)

# Convert the "contexts" feature to a sequence of strings
eval['contexts'] = eval['contexts'].str.split('|')

dataset = Dataset.from_dict(eval)

try:
    result = evaluate(
        dataset=dataset,
        metrics=[
            context_precision,
            faithfulness,
            answer_relevancy,
            context_recall,
        ],
        raise_exceptions=True
    )
    dff = result.to_pandas()
    dff.head()
except Exception as e:
    print(f"Error occurred during evaluation: {e}")
    print(dataset.features)

# %%
result.to_pandas()
# Out:
#                                              question  \
# 0   Under what circumstances and to what extent th...
# 1   Would the Sellers be responsible if after the ...
# 2                      How much is the escrow amount?
# 3   Is escrow amount grete then the Retention Amount?
# 4                  What is the purpose of the escrow?
# 5   May the Escrow Amount serve as a recourse for ...
# 6            Are there any conditions to the closing?
# 7   Are Change of Control Payments considered a Se...
# 8   Would the aggregate amount payable by the Buye...
# 9   Does the Buyer need to pay the Employees Closi...
# 10  Does any of the Sellers provide a representati...
# 11  Is any of the Sellers bound by a non-competiti...
# 12  Whose consent is required for the assignment o...
# 13  Does the Buyer needs the Sellers' consent in t...
#
#                                          ground_truth  \
# 0   Except in the case of fraud, the Sellers have ...
# 1                                                 Yes
# 2                                          $1,000,000
# 3                                                  No
# 4   To serve as a recourse of the Buyer in case of...
# 5                                                  No
# 6    No, as the signing and closing are simultaneous.
# 7   Yes. (See defining of Sellers Transaction Expe...
# 8                              Yes (See Section 2.07)
# 9                              No. (See Section 2.10)
# 10  No. Only the Company provides such a represent...
# 11                                                No.
# 12  If the assignment is to an Affiliate or purcha...
# 13  No. If the assignment is not part of a sale of...
#
#                                                answer  \
# 0   Based on the given contexts, it is indicated t...
# 1   Based on the provided contexts, the Sellers' R...
# 2   I'm sorry, but the documents provided do not s...
# 3   The documents provided do not contain informat...
# 4   The purpose of the escrow is to hold funds, sp...
# 5   Based on the provided context, it appears that...
# 6   I'm sorry, but the provided contexts do not co...
# 7   Based on the given contexts, it's not explicit...
# 8   Yes, according to the documents, if the actual...
# 9   No, the Buyer does not pay the Employee Closin...
# 10  I'm sorry, but I don't have enough information...
# 11  I'm sorry, but the context provided does not c...
# 12  Based on the provided contexts, it appears tha...
# 13  Yes, the Buyer needs the prior written approva...
#
#                                              contexts  context_precision  \
# 0   [['(b) Liability.  The Sellers ’ Representativ...                0.0
# 1   [['(b) Liability.  The Sellers ’ Representativ...                1.0
# 2   [['the Escrow Agreement (and any remaining bal...                1.0
# 3   [['the Escrow Agreement). \nSection 2.08  Escr...                1.0
# 4   [['the Escrow Agreement). \nSection 2.08  Escr...                1.0
# 5   [['provisions of this Agreement, of such dispu...                1.0
# 6   [['Section 2.03  The Closing.....................                1.0
# 7   [['“Change of Control Payment ” means (a) any ...                1.0
# 8   [['(a) Estimated Purchase Price.  The Purchase...                1.0
# 9   [['Company has approved cash bonuses, the aggr...                1.0
# 10  [['Each Seller agrees that it shall be respons...                1.0
# 11  [['Section 5.05  No Brokers.  The Buyer has no...                0.0
# 12  [['Buyer.  This Agreement and each Ancillary A...                1.0
# 13  [['Sellers ’ Representative acting for all of ...                1.0
#
#     faithfulness  answer_relevancy  context_recall
# 0       0.500000          0.000000             0.0
# 1       0.333333          0.909280             1.0
# 2       1.000000          0.000000             0.0
# 3       1.000000          0.000000             0.0
# 4       0.750000          0.988225             0.0
# 5       0.666667          0.000000             0.0
# 6       0.000000          0.000000             0.5
# 7       1.000000          0.000000             1.0
# 8       1.000000          0.963989             1.0
# 9       0.500000          0.987536             0.5
# 10      0.000000          0.000000             0.0
# 11      0.500000          0.946105             1.0
# 12      1.000000          0.927908             0.0
# 13      1.000000          0.941668             0.0

# %% [markdown]
# multiquery expansion approach

# %%
import pandas as pd
from datasets import Dataset

evaluation_data = pd.read_csv('../data/evaluation_data/updated_raptor_multiquery_chunk2000_evaluation.csv')
eval = evaluation_data.drop('Unnamed: 0', axis=1)

# Convert the "contexts" feature to a sequence of strings
eval['contexts'] = eval['contexts'].str.split('|')

dataset = Dataset.from_dict(eval)

try:
    result = evaluate(
        dataset=dataset,
        metrics=[
            context_precision,
            faithfulness,
            answer_relevancy,
            context_recall,
        ],
        raise_exceptions=True
    )
    dff = result.to_pandas()
    dff.head()
except Exception as e:
    print(f"Error occurred during evaluation: {e}")
    print(dataset.features)
# Out:
# Evaluating:   0%|          | 0/56 [00:00<?, ?it/s]

# %%
result.to_pandas()
# Out:
#                                              question  \
# 0   Under what circumstances and to what extent th...
# 1   Would the Sellers be responsible if after the ...
# 2                      How much is the escrow amount?
# 3   Is escrow amount grete then the Retention Amount?
# 4                  What is the purpose of the escrow?
# 5   May the Escrow Amount serve as a recourse for ...
# 6            Are there any conditions to the closing?
# 7   Are Change of Control Payments considered a Se...
# 8   Would the aggregate amount payable by the Buye...
# 9   Does the Buyer need to pay the Employees Closi...
# 10  Does any of the Sellers provide a representati...
# 11  Is any of the Sellers bound by a non-competiti...
# 12  Whose consent is required for the assignment o...
# 13  Does the Buyer needs the Sellers' consent in t...
#
#                                          ground_truth  \
# 0   Except in the case of fraud, the Sellers have ...
# 1                                                 Yes
# 2                                          $1,000,000
# 3                                                  No
# 4   To serve as a recourse of the Buyer in case of...
# 5                                                  No
# 6    No, as the signing and closing are simultaneous.
# 7   Yes. (See defining of Sellers Transaction Expe...
# 8                              Yes (See Section 2.07)
# 9                              No. (See Section 2.10)
# 10  No. Only the Company provides such a represent...
# 11                                                No.
# 12  If the assignment is to an Affiliate or purcha...
# 13  No. If the assignment is not part of a sale of...
#
#                                                answer  \
# 0   The Sellers are responsible for a breach of re...
# 1   Yes, the Sellers would be responsible if after...
# 2   The escrow amount is $1,000,000 as stated in t...
# 3   Based on the provided legal contract context, ...
# 4   The purpose of the escrow is to hold the Escro...
# 5   Answer: Yes, the Escrow Amount may serve as th...
# 6   Possible answers based on the provided legal c...
# 7   Based on the provided legal contract context, ...
# 8   Yes, the aggregate amount payable by the Buyer...
# 9   Based on the provided legal contract context, ...
# 10  Yes, one of the Sellers provides a representat...
# 11  Based on the provided legal contract context, ...
# 12  The consent of the other parties, including th...
# 13  Yes, the Buyer needs the Sellers' consent in t...
#
#                                              contexts  context_precision  \
# 0   [['-50- \n112923184_5 immediately after the Cl...                1.0
# 1   [['-50- \n112923184_5 immediately after the Cl...                1.0
# 2   [['-5- \n112923184_5 welfare plan within the m...                1.0
# 3   [['-20- \n112923184_5 (d) Resolution of Disput...                1.0
# 4   [['-20- \n112923184_5 (d) Resolution of Disput...                1.0
# 5   [['-20- \n112923184_5 (d) Resolution of Disput...                0.0
# 6   [['-19- \n112923184_5 (e) Treatment of Warrant...                1.0
# 7   [['-52- \n112923184_5 Section 5.02  Power and ...                1.0
# 8   [['-19- \n112923184_5 (e) Treatment of Warrant...                1.0
# 9   [['-20- \n112923184_5 (d) Resolution of Disput...                1.0
# 10  [['-ii- \n112923184_5 Section 3.19  Labor Matt...                1.0
# 11  [['-50- \n112923184_5 immediately after the Cl...                0.0
# 12  [['-52- \n112923184_5 Section 5.02  Power and ...                1.0
# 13  [['-52- \n112923184_5 Section 5.02  Power and ...                1.0
#
#     faithfulness  answer_relevancy  context_recall
# 0       0.250000          0.998220            0.00
# 1       0.000000          0.945254            1.00
# 2       0.500000          0.918254            1.00
# 3       0.250000          0.000000            0.75
# 4       0.500000          1.000000            1.00
# 5       1.000000          0.857398            1.00
# 6       0.333333          0.961111            0.00
# 7       0.250000          0.965768            1.00
# 8       0.333333          0.984329            1.00
# 9       0.750000          0.943681            0.00
# 10      0.000000          0.906909            0.00
# 11      0.666667          0.898613            0.00
# 12      1.000000          0.947969            0.50
# 13      1.000000          0.989693            1.00

# %%
dfd = result.to_pandas()
dfd["contexts"][2]
# Out:
# array(["['Escrow Agent shall release the Escrow Amount to Company Securityholders in accordance with \\nthe Escrow Agreement or (ii) the amount, if any, by which such estimated Purchase Price paid at \\nClosing in accordance with Section 2.05(a)(i) and Section 2.07(a) exceeds such re-calculated \\nfinal Purchase Price shall be paid to the Buyer, or its designee, in accordance with the terms of', 'the Escrow Agreement). \\nSection 2.08  Escrow.   \\n(a) At Closing, Buyer will deposit the Escrow Amount in escrow on behalf of the \\nSellers in accordance with the Escrow Agreement.  The Escrow Amount shall be held and, \\nsubject to Section 2.07, released to the Company Securityholders in accordance with the', '(b) At the Closing, Buyer shall deposit the Escrow Amount with the Escrow Agent to \\nbe held in a separate account (the “Escrow Account ”).  The Escrow Account shall be governed \\nby the terms of the Escrow Agreement.  All funds contained in the Escrow Account shall be held \\nin escrow and shall be available solely for the purpose of satisfying obligations of the Company', 'Section 2.08  Escrow ............................................................................................................. 19  \\nARTICLE III REPRESENTATIONS AND WARRANTIES REGARDING THE \\nACQUIRED COMPANIES. ......................................................................................................... 19', '-21- \\n112923184_5 provisions of the Escrow Agreement with the Company Securityholders being entitled to share in \\nsuch released amounts in accordance with their Pro Rata Percentages.  From and after the \\nClosing, Buyer and the Sellers ’ Representative will direct the Escrow Agent to disburse \\npayments from the Escrow Account in accordance with the purchase price adjustment provisions', 'the Escrow Agreement (and any remaining balance of the Escrow Amount not required to be \\npaid to the Buyer shall be released to Company Securityholders in accordance with the terms of \\nthe Escrow Agreement). \\nSection 2.08  Escrow.   \\n(a) At Closing, Buyer will deposit the Escrow Amount in escrow on behalf of the', 'Person or otherwise entitle any other Person to share in the equity, profits, earnings, losses or \\ngains of such Person (including stock appreciation, phantom stock, profit participation or other \\nsimilar rights). \\n“Escrow Amount ” means, $1,000,000']"],
#       dtype=object)

# %% [markdown]
# parentdoc with chunk size 200

# %%
import pandas as pd
from datasets import Dataset

evaluation_data = pd.read_csv('../data/evaluation_data/updated_raptor_parnentdoc_evaluation.csv')
eval = evaluation_data.drop('Unnamed: 0', axis=1)

# Convert the "contexts" feature to a sequence of strings
eval['contexts'] = eval['contexts'].str.split('|')


dataset = Dataset.from_dict(eval)

try:
    result = evaluate(
        dataset=dataset,
        metrics=[
            context_precision,
            faithfulness,
            answer_relevancy,
            context_recall,
        ],
        raise_exceptions=True
    )
    dff = result.to_pandas()
    dff.head()
except Exception as e:
    print(f"Error occurred during evaluation: {e}")
    print(dataset.features)
# Out:
# Evaluating:   0%|          | 0/56 [00:00<?, ?it/s]

# %%
result.to_pandas()
# Out:
#                                              question  \
# 0   Under what circumstances and to what extent th...
# 1   Would the Sellers be responsible if after the ...
# 2                      How much is the escrow amount?
# 3   Is escrow amount grete then the Retention Amount?
# 4                  What is the purpose of the escrow?
# 5   May the Escrow Amount serve as a recourse for ...
# 6            Are there any conditions to the closing?
# 7   Are Change of Control Payments considered a Se...
# 8   Would the aggregate amount payable by the Buye...
# 9   Does the Buyer need to pay the Employees Closi...
# 10  Does any of the Sellers provide a representati...
# 11  Is any of the Sellers bound by a non-competiti...
# 12  Whose consent is required for the assignment o...
# 13  Does the Buyer needs the Sellers' consent in t...
#
#                                          ground_truth  \
# 0   Except in the case of fraud, the Sellers have ...
# 1                                                 Yes
# 2                                          $1,000,000
# 3                                                  No
# 4   To serve as a recourse of the Buyer in case of...
# 5                                                  No
# 6    No, as the signing and closing are simultaneous.
# 7   Yes. (See defining of Sellers Transaction Expe...
# 8                              Yes (See Section 2.07)
# 9                              No. (See Section 2.10)
# 10  No. Only the Company provides such a represent...
# 11                                                No.
# 12  If the assignment is to an Affiliate or purcha...
# 13  No. If the assignment is not part of a sale of...
#
#                                                answer  \
# 0   Query:\nUnder what circumstances and to what e...
# 1   Summary of context:\nThe Sellers' Representati...
# 2   Query:\nHow much is the escrow amount?\n\nCont...
# 3   Yes, the escrow amount is greater than the Ret...
# 4   Query:\nWhat is the purpose of the escrow?\n\n...
# 5   Query:\nMay the Escrow Amount serve as a recou...
# 6   Query:\nAre there any conditions to the closin...
# 7   Query:\nAre Change of Control Payments conside...
# 8   Query:\nWould the aggregate amount payable by ...
# 9   Summary: Yes, the Buyer needs to deposit the E...
# 10  Query:\nDoes any of the Sellers provide a repr...
# 11  No, none of the Sellers are bound by a non-com...
# 12  The consent required for the assignment of the...
# 13  Query:\nDoes the Buyer need the Sellers' conse...
#
#                                              contexts  context_precision  \
# 0   [['(b) Liability.  The Sellers ’ Representativ...                1.0
# 1   [['Sellers ’ Representative ’s gross negligenc...                1.0
# 2   [['the Escrow Agreement). \nSection 2.08  Escr...                1.0
# 3   [['the Escrow Agreement). \nSection 2.08  Escr...                1.0
# 4   [['the Escrow Agreement). \nSection 2.08  Escr...                1.0
# 5   [['(b) Recovery from the Escrow Amount shall c...                1.0
# 6   [['Section 2.03  The Closing.....................                1.0
# 7   [['“Change of Control Payment ” means (a) any ...                1.0
# 8   [['Section 2.05(a)(i) (the “Estimated Purchase...                1.0
# 9   [['Closing Bonus Beneficiaries ”). At the Clos...                1.0
# 10  [['Sellers or the Sellers ’ Representative wit...                1.0
# 11  [['-54- \n112923184_5 (d) by a Party to its Re...                0.0
# 12  [['Buyer.  This Agreement and each Ancillary A...                1.0
# 13  [['-60- \n112923184_5  \n \nIf to any of the S...                1.0
#
#     faithfulness  answer_relevancy  context_recall
# 0       0.600000          0.998222        0.000000
# 1       0.600000          0.849665        1.000000
# 2       0.800000          1.000000        1.000000
# 3       1.000000          0.969896        0.000000
# 4       0.666667          1.000000        1.000000
# 5       1.000000          0.999999        0.000000
# 6       0.200000          1.000000        0.500000
# 7       0.666667          1.000000        1.000000
# 8       1.000000          0.995104        1.000000
# 9       1.000000          0.931518        0.000000
# 10      0.000000          1.000000        0.000000
# 11      0.000000          0.998732        0.666667
# 12      0.500000          0.978042        0.500000
# 13      1.000000          0.999213        1.000000

# %% [markdown]
# parentdoc characterspilter chunk 200

# %%
import pandas as pd
from datasets import Dataset


evaluation_data = pd.read_csv('../data/updated_raptor_parnentdoc_CharcterSplit_chunk200_evaluation.csv')
eval = evaluation_data.drop('Unnamed: 0', axis=1)

# Convert the "contexts" feature to a sequence of strings
eval['contexts'] = eval['contexts'].str.split('|')

dataset = Dataset.from_dict(eval)

# try:
result = evaluate(
    dataset=dataset,
    metrics=[
        context_precision,
        faithfulness,
        answer_relevancy,
        context_recall,
    ],
    raise_exceptions=True
)
result.to_pandas()
    # print(result.to_pandas())
# except Exception as e:
#     print(f"Error occurred during evaluation: {e}")
#     print(dataset.features)
# Out:
# Evaluating:   0%|          | 0/56 [00:00<?, ?it/s]
#                                              question  \
# 0   Under what circumstances and to what extent th...
# 1   Would the Sellers be responsible if after the ...
# 2                      How much is the escrow amount?
# 3   Is escrow amount grete then the Retention Amount?
# 4                  What is the purpose of the escrow?
# 5   May the Escrow Amount serve as a recourse for ...
# 6            Are there any conditions to the closing?
# 7   Are Change of Control Payments considered a Se...
# 8   Would the aggregate amount payable by the Buye...
# 9   Does the Buyer need to pay the Employees Closi...
# 10  Does any of the Sellers provide a representati...
# 11  Is any of the Sellers bound by a non-competiti...
# 12  Whose consent is required for the assignment o...
# 13  Does the Buyer needs the Sellers' consent in t...
#
#                                          ground_truth  \
# 0   Except in the case of fraud, the Sellers have ...
# 1                                                 Yes
# 2                                          $1,000,000
# 3                                                  No
# 4   To serve as a recourse of the Buyer in case of...
# 5                                                  No
# 6    No, as the signing and closing are simultaneous.
# 7   Yes. (See defining of Sellers Transaction Expe...
# 8                              Yes (See Section 2.07)
# 9                              No. (See Section 2.10)
# 10  No. Only the Company provides such a represent...
# 11                                                No.
# 12  If the assignment is to an Affiliate or purcha...
# 13  No. If the assignment is not part of a sale of...
#
#                                                answer  \
# 0   Query:\nUnder what circumstances and to what e...
# 1   The Sellers would be responsible if after the ...
# 2   The escrow amount to be deposited by the Buyer...
# 3   Answer:\nYes, the Escrow Amount is greater tha...
# 4   Query:\nWhat is the purpose of the escrow?\n\n...
# 5   Answer:\nThe Escrow Amount serves as the Buyer...
# 6   Answer:\nConditions to the closing include the...
# 7   No, Change of Control Payments are not conside...
# 8   Answer:\nYes, the aggregate amount payable by ...
# 9   No, the Buyer does not need to pay the Employe...
# 10  Section 3.13 Tax Matters: Each Acquired Compan...
# 11  Answer:\nSection 6.08(b) prohibits the Sellers...
# 12  Section 11.02 of the document specifies that t...
# 13  The Buyer does need the Sellers' consent in th...
#
#                                              contexts  context_precision  \
# 0   [['-61- \n112923184_5 Section 11.04  Provision...                1.0
# 1   [['-61- \n112923184_5 Section 11.04  Provision...                1.0
# 2   [['-20- \n112923184_5 (d) Resolution of Disput...                1.0
# 3   [['-21- \n112923184_5 provisions of the Escrow...                1.0
# 4   [['-20- \n112923184_5 (d) Resolution of Disput...                1.0
# 5   [['-21- \n112923184_5 provisions of the Escrow...                1.0
# 6   [['-19- \n112923184_5 (e) Treatment of Warrant...                1.0
# 7   [['-3- \n112923184_5 “Business Day ” means any...                1.0
# 8   [['-19- \n112923184_5 (e) Treatment of Warrant...                1.0
# 9   [['-20- \n112923184_5 (d) Resolution of Disput...                0.0
# 10  [["-36- \n112923184_5 reimbursed any illegal p...                1.0
# 11  [['-54- \n112923184_5 (d) by a Party to its Re...                0.0
# 12  [['-60- \n112923184_5  \n \nIf to any of the S...                1.0
# 13  [['-60- \n112923184_5  \n \nIf to any of the S...                1.0
#
#     faithfulness  answer_relevancy  context_recall
# 0       0.500000          0.998220        0.000000
# 1       0.500000          0.966359        1.000000
# 2       0.500000          0.881254        0.666667
# 3       0.000000          0.968463        0.000000
# 4       0.500000          1.000000        1.000000
# 5       0.333333          0.864113        0.000000
# 6       0.500000          0.965589        0.000000
# 7       0.000000          0.995380        1.000000
# 8       0.000000          0.992967        1.000000
# 9       0.000000          1.000000        0.000000
# 10      0.333333          0.867198        1.000000
# 11      0.500000          0.903340        1.000000
# 12      0.750000          0.902902        1.000000
# 13      0.000000          0.999213        1.000000

# %% [markdown]
# evaluation with cross encoder reranker implementation

# %%
import pandas as pd
from datasets import Dataset


evaluation_data = pd.read_csv('../data/evaluation_data/updated_raptor_crossendoderReranker_evaluation.csv')
eval = evaluation_data.drop('Unnamed: 0', axis=1)

# Convert the "contexts" feature to a sequence of strings
eval['contexts'] = eval['contexts'].str.split('|')

dataset = Dataset.from_dict(eval)

# try:
result = evaluate(
    dataset=dataset,
    metrics=[
        context_precision,
        faithfulness,
        answer_relevancy,
        context_recall,
    ],
    raise_exceptions=True
)
result.to_pandas()
    # print(result.to_pandas())
# except Exception as e:
#     print(f"Error occurred during evaluation: {e}")
#     print(dataset.features)
# Out:
# Evaluating:   0%|          | 0/56 [00:00<?, ?it/s]
#                                              question  \
# 0   Under what circumstances and to what extent th...
# 1   Would the Sellers be responsible if after the ...
# 2                      How much is the escrow amount?
# 3   Is escrow amount grete then the Retention Amount?
# 4                  What is the purpose of the escrow?
# 5   May the Escrow Amount serve as a recourse for ...
# 6            Are there any conditions to the closing?
# 7   Are Change of Control Payments considered a Se...
# 8   Would the aggregate amount payable by the Buye...
# 9   Does the Buyer need to pay the Employees Closi...
# 10  Does any of the Sellers provide a representati...
# 11  Is any of the Sellers bound by a non-competiti...
# 12  Whose consent is required for the assignment o...
# 13  Does the Buyer needs the Sellers' consent in t...
#
#                                          ground_truth  \
# 0   Except in the case of fraud, the Sellers have ...
# 1                                                 Yes
# 2                                          $1,000,000
# 3                                                  No
# 4   To serve as a recourse of the Buyer in case of...
# 5                                                  No
# 6    No, as the signing and closing are simultaneous.
# 7   Yes. (See defining of Sellers Transaction Expe...
# 8                              Yes (See Section 2.07)
# 9                              No. (See Section 2.10)
# 10  No. Only the Company provides such a represent...
# 11                                                No.
# 12  If the assignment is to an Affiliate or purcha...
# 13  No. If the assignment is not part of a sale of...
#
#                                                answer  \
# 0   The Sellers are responsible for a breach of re...
# 1   The provided information does not offer a defi...
# 2                    The escrow amount is $1,000,000.
# 3   No, the escrow amount is not greater than the ...
# 4   The purpose of the escrow is to hold funds tha...
# 5   Yes, the Escrow Amount may serve as a recourse...
# 6   Yes, there are conditions to the closing. Thes...
# 7   Yes, based on the provided information, Change...
# 8   Based on the provided information, it can be d...
# 9   No, the Buyer does not need to pay the Employe...
# 10  Based on the given information, it is not expl...
# 11  Based on the provided information, the sellers...
# 12  The consent required for the assignment of the...
# 13  Based on the provided information, it is not c...
#
#                                              contexts  context_precision  \
# 0   [['circumstances in which they were made. \nAR...                1.0
# 1   [['such Seller shall cause its Affiliates and ...                1.0
# 2   [['gains of such Person (including stock appre...                1.0
# 3   [['“Retention Amount ” means an amount equal t...                1.0
# 4   [['by the terms of the Escrow Agreement.  All ...                1.0
# 5   [['(b) Recovery from the Escrow Amount shall c...                1.0
# 6   [['(a) Buyer Closing Deliveries.  Upon the ter...                1.0
# 7   [['other experts and advisors so incurred and ...                1.0
# 8   [['(e) Purchase Price Adjustment.  If any of t...                1.0
# 9   [['Closing Bonus Beneficiaries ”). At the Clos...                1.0
# 10  [['reasonably requested by the Buyer, the Acqu...                1.0
# 11  [['decision of all the Sellers and shall be fi...                0.0
# 12  [['the subject matter of this Agreement or the...                1.0
# 13  [['such Seller shall cause its Affiliates and ...                1.0
#
#     faithfulness  answer_relevancy  context_recall
# 0       0.500000          0.987786             0.0
# 1       0.333333          0.000000             0.0
# 2       1.000000          0.982518             1.0
# 3       1.000000          0.969896             0.0
# 4       0.857143          1.000000             0.0
# 5       0.500000          0.916190             0.0
# 6       0.538462          0.932316             0.0
# 7       0.000000          0.987329             1.0
# 8       1.000000          0.984648             1.0
# 9       0.666667          1.000000             0.5
# 10      0.600000          0.000000             0.0
# 11      0.500000          0.923285             1.0
# 12      0.333333          0.951498             0.5
# 13      0.500000          0.000000             0.0

# %%
result.to_pandas()
# pprint.pp(dv["contexts"][0])
# Out:
#                                              question  \
# 0   Under what circumstances and to what extent th...
# 1   Would the Sellers be responsible if after the ...
# 2                      How much is the escrow amount?
# 3   Is escrow amount grete then the Retention Amount?
# 4                  What is the purpose of the escrow?
# 5   May the Escrow Amount serve as a recourse for ...
# 6            Are there any conditions to the closing?
# 7   Are Change of Control Payments considered a Se...
# 8   Would the aggregate amount payable by the Buye...
# 9   Does the Buyer need to pay the Employees Closi...
# 10  Does any of the Sellers provide a representati...
# 11  Is any of the Sellers bound by a non-competiti...
# 12  Whose consent is required for the assignment o...
# 13  Does the Buyer needs the Sellers' consent in t...
#
#                                          ground_truth  \
# 0   Except in the case of fraud, the Sellers have ...
# 1                                                 Yes
# 2                                          $1,000,000
# 3                                                  No
# 4   To serve as a recourse of the Buyer in case of...
# 5                                                  No
# 6    No, as the signing and closing are simultaneous.
# 7   Yes. (See defining of Sellers Transaction Expe...
# 8                              Yes (See Section 2.07)
# 9                              No. (See Section 2.10)
# 10  No. Only the Company provides such a represent...
# 11                                                No.
# 12  If the assignment is to an Affiliate or purcha...
# 13  No. If the assignment is not part of a sale of...
#
#                                                answer  \
# 0   The Sellers are responsible for a breach of re...
# 1   The provided information does not offer a defi...
# 2                    The escrow amount is $1,000,000.
# 3   No, the escrow amount is not greater than the ...
# 4   The purpose of the escrow is to hold funds tha...
# 5   Yes, the Escrow Amount may serve as a recourse...
# 6   Yes, there are conditions to the closing. Thes...
# 7   Yes, based on the provided information, Change...
# 8   Based on the provided information, it can be d...
# 9   No, the Buyer does not need to pay the Employe...
# 10  Based on the given information, it is not expl...
# 11  Based on the provided information, the sellers...
# 12  The consent required for the assignment of the...
# 13  Based on the provided information, it is not c...
#
#                                              contexts  context_precision  \
# 0   [['circumstances in which they were made. \nAR...                1.0
# 1   [['such Seller shall cause its Affiliates and ...                1.0
# 2   [['gains of such Person (including stock appre...                1.0
# 3   [['“Retention Amount ” means an amount equal t...                1.0
# 4   [['by the terms of the Escrow Agreement.  All ...                1.0
# 5   [['(b) Recovery from the Escrow Amount shall c...                1.0
# 6   [['(a) Buyer Closing Deliveries.  Upon the ter...                1.0
# 7   [['other experts and advisors so incurred and ...                1.0
# 8   [['(e) Purchase Price Adjustment.  If any of t...                1.0
# 9   [['Closing Bonus Beneficiaries ”). At the Clos...                1.0
# 10  [['reasonably requested by the Buyer, the Acqu...                1.0
# 11  [['decision of all the Sellers and shall be fi...                0.0
# 12  [['the subject matter of this Agreement or the...                1.0
# 13  [['such Seller shall cause its Affiliates and ...                1.0
#
#     faithfulness  answer_relevancy  context_recall
# 0       0.500000          0.987786             0.0
# 1       0.333333          0.000000             0.0
# 2       1.000000          0.982518             1.0
# 3       1.000000          0.969896             0.0
# 4       0.857143          1.000000             0.0
# 5       0.500000          0.916190             0.0
# 6       0.538462          0.932316             0.0
# 7       0.000000          0.987329             1.0
# 8       1.000000          0.984648             1.0
# 9       0.666667          1.000000             0.5
# 10      0.600000          0.000000             0.0
# 11      0.500000          0.923285             1.0
# 12      0.333333          0.951498             0.5
# 13      0.500000          0.000000             0.0

# %%
pprint.pp(dv["contexts"][3])
# Out:
# array(["[', accountants, and financial advisors. “ retention amount ” means an amount equal to $ 5, 000, 000. “ section 102 ” means section 102 of the income tax ordinance. “ section 102 options ” means options granted and subject to tax pursuant to section 102 ( b ) ( 2 ) of the ordinance.', '##ursement promptly upon the resolution, in accordance with the provisions of this agreement, of such dispute. ( b ) recovery from the escrow amount shall constitute the buyer ’ s exclusive remedy against the company securityholders in connection with any claim relating to any adjustments of the purchase price ( as set forth in section 2. 07 ( e ) ) and any such claim shall expire upon the termination of the escrow agreement. section 2. 09 withholding rights. ( a ) ( a ) notwithstanding any other provision of this agreement, each of the buyer or anyone acting on its behalf, the paying agent, the escrow agent and the section 102 trustee and any other applicable withholding agent ( each a “ payor ” ), shall be entitled to deduct and withhold from the closing cash payment and from any other payments otherwise required pursuant to this agreement, such amount in cash as the buyer and / or such anyone acting on its behalf is required to deduct and withhold with respect to any payments under the code or any provision of state, local, provincial or foreign law, unless the applicable payee ( as defined below ) provides the payor, at least five days prior to the proposed date of such payment, with a valid withholding certificate obtained from the', 'buyer shall deposit the escrow amount with the escrow agent to be held in a separate account ( the “ escrow account ” ). the escrow account shall be governed by the terms of the escrow agreement. all funds contained in the escrow account shall be held in escrow and shall be available solely for the purpose of satisfying obligations of the company securityholders, if any, as provided in section 2. 07 ( f ). section 2. 05 closing deliveries. ( a ) buyer closing deliveries. upon the terms and subject to the conditions set forth in this agreement, the buyer shall deliver or cause to be delivered at the closing the following : ( i ) pay or cause to be paid the closing cash amounts as set forth above, each payment by wire transfer of immediately available funds denominated in u. s. dollars to an account or accounts specified on the allocation statement ; 6 note to draft : draft to be updated as necessary to provide that any payments in respec t of shares held under section 102 be paid to the section 102 trustee.', ', and ( i ) the buyer shall pay in cash to eac h company securityholder by wire transfer of immediately available funds its pro rata percentage of the amount, if any, by which such re - calculated final purchase price exceeds the estimated purchase price paid at closing in accordance with section 2. 05 ( a ) ( i ) and section 2. 07 ( a ) and the escrow agent shall release the escrow amount to company securityholders in accordance with the escrow agreement or ( ii ) the amount, if any, by which such estimated purchase price paid at closing in accordance with section 2. 05 ( a ) ( i ) and section 2. 07 ( a ) exceeds such re - calculated final purchase price shall be paid to the buyer, or its designee, in accordance with the terms of the escrow agreement ( and any remaining balance of the escrow amount not required to be paid to the buyer shall be released to company securityholders in accordance with the terms of the escrow agreement ). section 2. 08 escrow. ( a ) at closing, buyer will deposit the escrow amount in escrow on behalf of the sellers in accordance with the escrow agreement. the escrow amount shall be held and, subject to section 2. 07,', 'of all cash and cash equivalents of the acquired companies as of immediately prior to the closing, less ( without duplication ) the amount of outstanding checks as of the closing. “ closing debt amount ” means the amount of debt of the acquired compani ...
#       dtype=object)

# %%
pprint.pp(dv["contexts"][4])
# Out:
# array(["['buyer shall deposit the escrow amount with the escrow agent to be held in a separate account ( the “ escrow account ” ). the escrow account shall be governed by the terms of the escrow agreement. all funds contained in the escrow account shall be held in escrow and shall be available solely for the purpose of satisfying obligations of the company securityholders, if any, as provided in section 2. 07 ( f ). section 2. 05 closing deliveries. ( a ) buyer closing deliveries. upon the terms and subject to the conditions set forth in this agreement, the buyer shall deliver or cause to be delivered at the closing the following : ( i ) pay or cause to be paid the closing cash amounts as set forth above, each payment by wire transfer of immediately available funds denominated in u. s. dollars to an account or accounts specified on the allocation statement ; 6 note to draft : draft to be updated as necessary to provide that any payments in respec t of shares held under section 102 be paid to the section 102 trustee.', 'settle, compromise or otherwise resolve all claims, disputes and actions, authorize payments in respect of any such claims, disputes or actions, and take all other actions, in each case, with respect to the matters set forth in section 2. 06, article vii, article viii or any other actions directly or indirectly arising out of or relating to this agreement, the escrow agreement or the contemplated transactions ; ( iii ) receive and give all notices, make all decisions and take all other actions on behalf of the sellers in connection with the escrow account established pursuant to the escrow agreement, including giving any instructions or authorizations to the escrow agent to pay from such escrow account any amounts owed by the sellers pursuant to this agreement or the escrow agreement or otherwise in connection with the contemplated transactions ; ( iv ) execute and deliver, should it elect to do so in its good faith discretion, on behalf of the sellers, any amendment to, or waiver of, any term or provision of this agreement or the escrow agreement, or any consent, acknowledgment or release relating to this agreement or the escrow agreement ; and ( v ) take all other actions permitted or required to be taken by or on behalf of the sellers under this agreement or the es', '- 21 - 112923184 _ 5 provisions of the escrow agreement with the company securityholders being entitled to share in such released amounts in accordance with their pro rata percentages. from and after the closing, buyer and the sellers ’ representative will direct the escrow agent to disburse payments from the escrow account in accordance with the purchase price adjustment provisions of this agreement and the terms of the escrow agreement including : ( a ) in the case of any disbursement that is required by the terms of this agreement and as to which there is no dispute ( or as to which the disputing party has failed to notify the escrow agent and the other parties of its dispute in accordance with any applicable requirements under this agreement and the escrow agreement ), they will provide prompt joint payment instructions directing the escrow agent to make such disbursement and ( b ) in the case of a disbursement as to which either the buyer or the seller ’ s representative has notified the other and the escrow agent ( in accordance with any notice and timing requirements applicable under this agreement and the escrow agreement ) that there is a good faith dispute, they will provide joint payment instructions to the escrow agent to direct the appropriate disb', ', with respect to any specified person, any other person directly or indirectly controlling, controlled by, or under direct or indirect common control with such specified person. for purposes of the foregoing, a person shall be deemed to control a specified person if such person ( or a family member of such person ) possesses, directly or indirectly, the power to direct or cause the di ...
#       dtype=object)
